# %% [markdown]
# # Azure Fuction

# %% [markdown]
# Aqui crearemos una Azure Fuction
# ![image.png](attachment:f2132e3f-c9bd-4a45-a6dc-795f323a0c33.png)
# ![image.png](attachment:ab2d2c37-ecd3-4361-8686-3edfb9e2e717.png)

# %% [markdown]
# Todo lo demás es predeterminado, excepto por las etiquetas, ahi agregamos CreatedBy, Area y Ciclo
# ![image.png](attachment:44a020a4-655e-4384-8a2a-e7c8e0857c01.png)

# %% [markdown]
# Asi quedaría:
# ![image.png](attachment:70e19deb-4dac-4992-a7aa-a301362b9aba.png)

# %% [markdown]
# Nos vamos al URL y aparece esto:
# ![image.png](attachment:939e3f7a-7bcb-447d-bd31-dbcabf1a412d.png)

# %% [markdown]
# Regresamos al recurso lab04-dr y buscamos funciones:
# Vamos a crear una función:
# Un HTTP trigger
# ![image.png](attachment:caa9701b-281a-49c0-9aa5-b7729f315d2d.png)

# %% [markdown]
# Seleccionamos HTTP trigger y vamos a Código y prueba:
# ![image.png](attachment:aab6105f-7ae7-4dfa-bf18-eb24418c98de.png)

# %% [markdown]
# Obtenemos el URL de la función:
# ![image.png](attachment:fe044182-ab86-4e2a-9f84-d1ddb371489c.png)

# %% [markdown]
# Esto es lo primero que vamos a obtener:
# ![image.png](attachment:925e6285-15be-4c66-84af-1bd6f29c3632.png)

# %% [markdown]
# Agregamos nuestro nombre:
# ![image.png](attachment:aeadb972-85bd-41a5-82bc-8ed179e49833.png)

# %% [markdown]
# Y listo sería todo
